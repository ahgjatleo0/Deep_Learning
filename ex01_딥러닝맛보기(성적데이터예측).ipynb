# %%
# 실행
# shift + enter : 현재 셀을 실행하고 아래로 커서 이동(아래 셀이 없다면 생성하고 커서 이동)
# ctrl + enter : 현재 셀 실행

# 셀 생성
# 위에 셀 생성 : ctrl + m + a
# 아래에 셀 생성 : ctrl + m + b

# 마크다운 : ctrl + m + m (연속적으로 누르고 있으면 자동 마크다운 변환)
# 원래상태로 전환 : ctrl + m + y

# 셀 삭제 : ctrl + m + d
# 하나의 셀 안에 있는 동일한 단어 한꺼번에 선택 : ctrl + shift + l

# %%
# /content/drive/MyDrive/Colab Notebooks/DeepLearning_빅데/data/student-mat.gsheet
# 현재 경로
# %pwd
# 경로 이동
# %cd /content/drive/MyDrive/Colab Notebooks/DeepLearning_빅데
# Out:
# /content/drive/MyDrive/Colab Notebooks/DeepLearning_빅데

# %% [markdown]
# ### 목표
#  - 학생 수학 성적 예측하는 회귀 모델을 만들어보자!
#  - keras를 이용하여 딥러닝 신경망을 구성해보자!

# %%
# 데이터 불러오기
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# csv, 구분자 : ';'
data = pd.read_csv('data/student-mat.csv', delimiter=';')
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
# 컬럼명 출력
data.columns

# 답 데이터 : G3(수학 성적)
# 특성 데이터 : studytime(공부 시간), 특성 1개 학습 진행
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
data['G3'] # 연속적인 수치값 성적 -> 회귀
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 390     9
# 391    16
# 392     7
# 393    10
# 394     9
# Name: G3, Length: 395, dtype: int64

# %%
# 문제와 답으로 분리
X = data['studytime'] # 공부시간 1차원 배열
# data.loc[:, 'studytime']
y = data['G3'] # G3 1차원 배열
# data.loc[:. 'G3']

# Train이랑 test 분리 7:3, 3
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.3, random_state=3)

# 크기 확인
print('훈련용 : ', X_train.shape, y_train.shape) # 특성 1개
print('테스트용 : ', X_test.shape, y_test.shape)
# Out:
# 훈련용 :  (276,) (276,)
# 테스트용 :  (119,) (119,)

# %% [markdown]
# #### 신경망 모델 만들기
#  1. 신경망 구조 설계 : 뼈대 구축, 층 쌓기
#  2. 신경망 학습/평가 방법 설정
#  3. 신경망 모델 학습 및 결과 시각화
#  4. 모델 평가 및 예측

# %%
# 1. 신경망 구조 설계
from tensorflow.keras import Sequential # 뼈대 구축 기능
from tensorflow.keras.layers import Dense, Activation # 층 쌓기

# %%
# 모델 정의
model = Sequential() # 뼈대 구축

# 층 쌓기 시작!
# 입력층(데이터 설명 => 특성 개수 1개) + 중간층 1개(뉴런 or 유닛 개수 설정, activation)
model.add(Dense(units = 4, input_dim = 1))
model.add(Activation('sigmoid')) # 활성화 함수 : 반응 결과 정리하는 기능

# 출력층 회귀에서 항상 units = 1, 활성화 함수 activation = 'linear'(항등함수라서 생략가능)
model.add(Dense(units = 1))
# model.add(Activation('linear'))


# 요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 8
#
#  activation (Activation)     (None, 4)                 0
#
#  dense_1 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 2. 신경망 학습/ 평가 방법 설정
# compile()
# 모델의 설계를 pc가 이해할 수 있도록 번역하는 과정
# 오차 계산 공식, 최적화 함수, 평가 지표(척도)
# 회귀
model.compile(loss ='mse', # 손실함수(비용함수) : mse(평균제곱오차) -> 회귀
              optimizer = 'sgd' # 최적화 함수 : 경사하강법 종류 설정 -> 확률적 경사 하강법
              ) # metrics 키워드 사용 'mse' 활용

# %%
# 3. 학습
# h 라는 변수에 학습 현황 저장
# h = model.fit(훈련문제, 훈련답, 반복횟수 = )
h = model.fit(X_train, y_train, epochs= 200)
h

# h안에 있는 학습 히스토리에 접근
h.history['loss']
# Out:
# Epoch 1/200
# 9/9 [==============================] - 0s 2ms/step - loss: 20.
200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6415
# Epoch 126/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6722
# Epoch 127/200
# 9/9 [==============================] - 0s 5ms/step - loss: 20.6148
# Epoch 128/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.7191
# Epoch 129/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6385
# Epoch 130/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6643
# Epoch 131/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6576
# Epoch 132/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6104
# Epoch 133/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6552
# Epoch 134/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6490
# Epoch 135/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6568
# Epoch 136/200
# 9/9 [==============================] - 0s 5ms/step - loss: 20.6257
# Epoch 137/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6556
# Epoch 138/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6898
# Epoch 139/200
# 9/9 [==============================] - 0s 5ms/step - loss: 20.6905
# Epoch 140/200
# 9/9 [==============================] - 0s 6ms/step - loss: 20.7102
# Epoch 141/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6699
# Epoch 142/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6418
# Epoch 143/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6617
# Epoch 144/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6502
# Epoch 145/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6599
# Epoch 146/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6544
# Epoch 147/200
# 9/9 [==============================] - 0s 5ms/step - loss: 20.7019
# Epoch 148/200
# 9/9 [==============================] - 0s 5ms/step - loss: 20.6636
# Epoch 149/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6926
# Epoch 150/200
# 9/9 [==============================] - 0s 5ms/step - loss: 20.6278
# Epoch 151/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6520
# Epoch 152/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6937
# Epoch 153/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6436
# Epoch 154/200
# 9/9 [==============================] - 0s 7ms/step - loss: 20.6611
# Epoch 155/200
# 9/9 [==============================] - 0s 10ms/step - loss: 20.6400
# Epoch 156/200
# 9/9 [==============================] - 0s 5ms/step - loss: 20.6335
# Epoch 157/200
# 9/9 [==============================] - 0s 5ms/step - loss: 20.6424
# Epoch 158/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6579
# Epoch 159/200
# 9/9 [==============================] - 0s 5ms/step - loss: 20.6596
# Epoch 160/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6525
# Epoch 161/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6408
# Epoch 162/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6649
# Epoch 163/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.7332
# Epoch 164/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6358
# Epoch 165/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6304
# Epoch 166/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6141
# Epoch 167/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6457
# Epoch 168/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6615
# Epoch 169/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6358
# Epoch 170/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6936
# Epoch 171/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6283
# Epoch 172/200
# 9/9 [==============================] - 0s 6ms/step - loss: 20.6454
# Epoch 173/200
# 9/9 [==============================] - 0s 5ms/step - loss: 20.7004
# Epoch 174/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6138
# Epoch 175/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6600
# Epoch 176/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6786
# Epoch 177/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6232
# Epoch 178/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.7440
# Epoch 179/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6681
# Epoch 180/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6679
# Epoch 181/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6815
# Epoch 182/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.7347
# Epoch 183/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6839
# Epoch 184/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6849
# Epoch 185/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6470
# Epoch 186/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.7312
# Epoch 187/200
# 9/9 [==============================] - 0s 5ms/step - loss: 20.6326
# Epoch 188/200
# 9/9 [==============================] - 0s 5ms/step - loss: 20.6756
# Epoch 189/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6454
# Epoch 190/200
# 9/9 [==============================] - 0s 5ms/step - loss: 20.6535
# Epoch 191/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6337
# Epoch 192/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6365
# Epoch 193/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6547
# Epoch 194/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6437
# Epoch 195/200
# 9/9 [==============================] - 0s 4ms/step - loss: 20.6311
# Epoch 196/200
# 9/9 [==============================] - 0s 5ms/step - loss: 20.6352
# Epoch 197/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6287
# Epoch 198/200
# 9/9 [==============================] - 0s 6ms/step - loss: 20.6732
# Epoch 199/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6571
# Epoch 200/200
# 9/9 [==============================] - 0s 3ms/step - loss: 20.6212
# [20.650197982788086,
#  20.66609001159668,
#  20.671558380126953,
#  20.669517517089844,
#  20.641448974609375,
#  20.64149284362793,
#  20.673067092895508,
#  20.71054458618164,
#  20.667612075805664,
#  20.64385223388672,
#  20.664287567138672,
#  20.634578704833984,
#  20.688682556152344,
#  20.65488624572754,
#  20.6611328125,
#  20.681507110595703,
#  20.62564468383789,
#  20.625635147094727,
#  20.644548416137695,
#  20.63934326171875,
#  20.740602493286133,
#  20.634323120117188,
#  20.67822265625,
#  20.660297393798828,
#  20.683786392211914,
#  20.650915145874023,
#  20.65178108215332,
#  20.700366973876953,
#  20.677125930786133,
#  20.640419006347656,
#  20.71285057067871,
#  20.693086624145508,
#  20.63897705078125,
#  20.693004608154297,
#  20.676536560058594,
#  20.657520294189453,
#  20.66019058227539,
#  20.628429412841797,
#  20.655759811401367,
#  20.64521598815918,
#  20.665760040283203,
#  20.648962020874023,
#  20.682235717773438,
#  20.688522338867188,
#  20.643199920654297,
#  20.63163948059082,
#  20.67807388305664,
#  20.628721237182617,
#  20.643396377563477,
#  20.677337646484375,
#  20.64727783203125,
#  20.70428466796875,
#  20.6663875579834,
#  20.74207305908203,
#  20.64410400390625,
#  20.679800033569336,
#  20.664854049682617,
#  20.673137664794922,
#  20.668718338012695,
#  20.67595863342285,
#  20.65977668762207,
#  20.64787483215332,
#  20.690149307250977,
#  20.658933639526367,
#  20.670133590698242,
#  20.669410705566406,
#  20.6374568939209,
#  20.628854751586914,
#  20.63981056213379,
#  20.662416458129883,
#  20.702037811279297,
#  20.68472671508789,
#  20.6641788482666,
#  20.694332122802734,
#  20.67190170288086,
#  20.70973777770996,
#  20.619508743286133,
#  20.688833236694336,
#  20.62616539001465,
#  20.633785247802734,
#  20.6773738861084,
#  20.653213500976562,
#  20.66058921813965,
#  20.653953552246094,
#  20.680017471313477,
#  20.742700576782227,
#  20.633487701416016,
#  20.698509216308594,
#  20.662479400634766,
#  20.638816833496094,
#  20.633487701416016,
#  20.63726043701172,
#  20.628969192504883,
#  20.69678497314453,
#  20.64757537841797,
#  20.642148971557617,
#  20.738927841186523,
#  20.627613067626953,
#  20.662961959838867,
#  20.648597717285156,
#  20.665979385375977,
#  20.690166473388672,
#  20.672924041748047,
#  20.664602279663086,
#  20.67745590209961,
#  20.662057876586914,
#  20.704498291015625,
#  20.642656326293945,
#  20.684494018554688,
#  20.717859268188477,
#  20.64251708984375,
#  20.640932083129883,
#  20.63823127746582,
#  20.631677627563477,
#  20.66128921508789,
#  20.708782196044922,
#  20.673110961914062,
#  20.65599822998047,
#  20.6806697845459,
#  20.661775588989258,
#  20.71672248840332,
#  20.671518325805664,
#  20.68651008605957,
#  20.653581619262695,
#  20.641460418701172,
#  20.67218017578125,
#  20.61479377746582,
#  20.719139099121094,
#  20.63845443725586,
#  20.664268493652344,
#  20.65763282775879,
#  20.61041259765625,
#  20.655170440673828,
#  20.649015426635742,
#  20.65679931640625,
#  20.62574577331543,
#  20.6556453704834,
#  20.68980598449707,
#  20.690467834472656,
#  20.710168838500977,
#  20.669858932495117,
#  20.64181137084961,
#  20.661727905273438,
#  20.650163650512695,
#  20.65987205505371,
#  20.65439224243164,
#  20.701913833618164,
#  20.66359519958496,
#  20.69264030456543,
#  20.627819061279297,
#  20.652006149291992,
#  20.693693161010742,
#  20.64362335205078,
#  20.661069869995117,
#  20.639963150024414,
#  20.633453369140625,
#  20.64238739013672,
#  20.65793800354004,
#  20.659626007080078,
#  20.65254020690918,
#  20.64084815979004,
#  20.664875030517578,
#  20.733213424682617,
#  20.63579750061035,
#  20.630395889282227,
#  20.614145278930664,
#  20.645715713500977,
#  20.661508560180664,
#  20.63581085205078,
#  20.69361686706543,
#  20.628292083740234,
#  20.64536476135254,
#  20.70042610168457,
#  20.61383056640625,
#  20.659969329833984,
#  20.67860984802246,
#  20.623214721679688,
#  20.743955612182617,
#  20.668149948120117,
#  20.667949676513672,
#  20.681528091430664,
#  20.734668731689453,
#  20.68386459350586,
#  20.68488883972168,
#  20.647008895874023,
#  20.731163024902344,
#  20.63262176513672,
#  20.675628662109375,
#  20.64544677734375,
#  20.653539657592773,
#  20.633678436279297,
#  20.636537551879883,
#  20.654747009277344,
#  20.64366912841797,
#  20.63109016418457,
#  20.63515853881836,
#  20.628677368164062,
#  20.673168182373047,
#  20.657135009765625,
#  20.621204376220703]

# %%
# 모델 평가
# score -> evaluate()
# 오차 mse 
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 21.1075
# 21.107454299926758

# %%
# 에측
model.predict(X_test)
